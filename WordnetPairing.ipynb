# %%
import nltk
from textblob import Word
import pandas as pd

# %%
from nltk.corpus import wordnet as wn
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/andrewcgaitskell/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
wn.synsets('dog')[0].name()
# Out:
# 'dog.n.01'

# %%
root = wn.synsets('dog')
len(root)
# Out:
# 8

# %%
root
# Out:
# [Synset('dog.n.01'),
#  Synset('frump.n.01'),
#  Synset('dog.n.03'),
#  Synset('cad.n.01'),
#  Synset('frank.n.02'),
#  Synset('pawl.n.01'),
#  Synset('andiron.n.01'),
#  Synset('chase.v.01')]

# %%
frump = wn.synsets('cad')
frump
# Out:
# [Synset('cad.n.01'), Synset('computer-aided_design.n.01')]

# %%
len(root[0].lemmas())
# Out:
# 3

# %%
wn.synsets('dog', pos=wn.VERB)
# Out:
# [Synset('chase.v.01')]

# %%
print(wn.synset('dog.n.01').definition())
# Out:
# a member of the genus Canis (probably descended from the common wolf) that has been domesticated by man since prehistoric times; occurs in many breeds

# %%
len(wn.synset('dog.n.01').examples())
print(wn.synset('dog.n.01').examples()[0])
# Out:
# the dog barked all night

# %%
wn.synset('dog.n.01').lemmas()
# Out:
# [Lemma('dog.n.01.dog'),
#  Lemma('dog.n.01.domestic_dog'),
#  Lemma('dog.n.01.Canis_familiaris')]

# %%
[str(lemma.name()) for lemma in wn.synset('dog.n.01').lemmas()]
# Out:
# ['dog', 'domestic_dog', 'Canis_familiaris']

# %%
##Synsets

#Synset: a set of synonyms that share a common meaning.

def getsynsets(synset_in):
    sn_in = wn.synset(synset_in)
    lemmas = [str(lemma.name()) for lemma in sn_in.lemmas()]
    synsets = wn.synsets(lemmas[0])
    return synsets

# %%
sn_in = wn.synset('dog.n.01')
print(sn_in.name())
sns_out = getsynsets(sn_in.name())
sns_out
# Out:
# dog.n.01
# [Synset('dog.n.01'),
#  Synset('frump.n.01'),
#  Synset('dog.n.03'),
#  Synset('cad.n.01'),
#  Synset('frank.n.02'),
#  Synset('pawl.n.01'),
#  Synset('andiron.n.01'),
#  Synset('chase.v.01')]

# %%
def get_parent_child(synset_name_in):
    #dog = wn.synset('dog.n.01')
    sn_in = wn.synset(synset_name_in)
    lemmas = [str(lemma.name()) for lemma in sn_in.lemmas()]
    synsets = wn.synsets(lemmas[0])
    #root = wn.synsets(word_in)
    master = synsets[0].name()
    #master = wn.synset('dog.n.01')
    #root_hyper = root.hypernyms()
    #root_hypo = root.hyponyms()
    parent_child = []
    for x in range(len(synsets)):
        #for y in len(dog_hypo):
        #    print(dog[x],dog_hypo[y])
        #print(x, master, root[x])
        append_this = [master, synsets[x].name()]
        parent_child.append(append_this)
        for y in synsets[x].hyponyms():
            #print(x, root[x],y)
            append_this = [synsets[x].name(),y.name()]
            parent_child.append(append_this)

    return parent_child
l = get_parent_child('dog.n.01')
l
# Out:
# [['dog.n.01', 'dog.n.01'],
#  ['dog.n.01', 'basenji.n.01'],
#  ['dog.n.01', 'corgi.n.01'],
#  ['dog.n.01', 'cur.n.01'],
#  ['dog.n.01', 'dalmatian.n.02'],
#  ['dog.n.01', 'great_pyrenees.n.01'],
#  ['dog.n.01', 'griffon.n.02'],
#  ['dog.n.01', 'hunting_dog.n.01'],
#  ['dog.n.01', 'lapdog.n.01'],
#  ['dog.n.01', 'leonberg.n.01'],
#  ['dog.n.01', 'mexican_hairless.n.01'],
#  ['dog.n.01', 'newfoundland.n.01'],
#  ['dog.n.01', 'pooch.n.01'],
#  ['dog.n.01', 'poodle.n.01'],
#  ['dog.n.01', 'pug.n.01'],
#  ['dog.n.01', 'puppy.n.01'],
#  ['dog.n.01', 'spitz.n.01'],
#  ['dog.n.01', 'toy_dog.n.01'],
#  ['dog.n.01', 'working_dog.n.01'],
#  ['dog.n.01', 'frump.n.01'],
#  ['dog.n.01', 'dog.n.03'],
#  ['dog.n.01', 'cad.n.01'],
#  ['cad.n.01', 'perisher.n.01'],
#  ['dog.n.01', 'frank.n.02'],
#  ['frank.n.02', 'vienna_sausage.n.01'],
#  ['dog.n.01', 'pawl.n.01'],
#  ['dog.n.01', 'andiron.n.01'],
#  ['dog.n.01', 'chase.v.01'],
#  ['chase.v.01', 'hound.v.01'],
#  ['chase.v.01', 'quest.v.02'],
#  ['chase.v.01', 'run_down.v.07'],
#  ['chase.v.01', 'tree.v.03']]

# %%
l = get_parent_child('dog.n.01')
start = wn.synset('dog.n.01')
finish = wn.synsets('gold')[0]
new_l = []
#len(l)
for s in l:
    try:
        sn = wn.synset(s[0])
        ps = sn.path_similarity(finish)
        ps_str = f"{ps:.9f}"
        #print(ps_str)
        s_raw = s.copy()
        s_raw.append(ps_str)
        new_l.append(s_raw)
    except:
        continue
new_l
# Out:
# [['dog.n.01', 'dog.n.01', '0.052631579'],
#  ['dog.n.01', 'basenji.n.01', '0.052631579'],
#  ['dog.n.01', 'corgi.n.01', '0.052631579'],
#  ['dog.n.01', 'cur.n.01', '0.052631579'],
#  ['dog.n.01', 'dalmatian.n.02', '0.052631579'],
#  ['dog.n.01', 'great_pyrenees.n.01', '0.052631579'],
#  ['dog.n.01', 'griffon.n.02', '0.052631579'],
#  ['dog.n.01', 'hunting_dog.n.01', '0.052631579'],
#  ['dog.n.01', 'lapdog.n.01', '0.052631579'],
#  ['dog.n.01', 'leonberg.n.01', '0.052631579'],
#  ['dog.n.01', 'mexican_hairless.n.01', '0.052631579'],
#  ['dog.n.01', 'newfoundland.n.01', '0.052631579'],
#  ['dog.n.01', 'pooch.n.01', '0.052631579'],
#  ['dog.n.01', 'poodle.n.01', '0.052631579'],
#  ['dog.n.01', 'pug.n.01', '0.052631579'],
#  ['dog.n.01', 'puppy.n.01', '0.052631579'],
#  ['dog.n.01', 'spitz.n.01', '0.052631579'],
#  ['dog.n.01', 'toy_dog.n.01', '0.052631579'],
#  ['dog.n.01', 'working_dog.n.01', '0.052631579'],
#  ['dog.n.01', 'frump.n.01', '0.052631579'],
#  ['dog.n.01', 'dog.n.03', '0.052631579'],
#  ['dog.n.01', 'cad.n.01', '0.052631579'],
#  ['cad.n.01', 'perisher.n.01', '0.058823529'],
#  ['dog.n.01', 'frank.n.02', '0.052631579'],
#  ['frank.n.02', 'vienna_sausage.n.01', '0.055555556'],
#  ['dog.n.01', 'pawl.n.01', '0.052631579'],
#  ['dog.n.01', 'andiron.n.01', '0.052631579'],
#  ['dog.n.01', 'chase.v.01', '0.052631579'],
#  ['chase.v.01', 'hound.v.01', '0.066666667'],
#  ['chase.v.01', 'quest.v.02', '0.066666667'],
#  ['chase.v.01', 'run_down.v.07', '0.066666667'],
#  ['chase.v.01', 'tree.v.03', '0.066666667']]

# %%
def path_sim1(child,finish):
    child_sn = wn.synset(child)
    finish_sn = wn.synset(finish)
    ps = child_sn.path_similarity(finish_sn)
    return ps

# %%
def path_sim(child,finish):
    try:
        child_sn = wn.synset(child)
        finish_sn = wn.synset(finish)
        ps = child_sn.path_similarity(finish_sn)
    except:
        ps = 0
    return ps

# %% [markdown]
# start = wn.synsets('dog')[0]
# finish = wn.synsets('gold')[0]
#
# x = path_sim(start,finish)
# #x
# syntext = "Synset('dog.n.01')"
# syntext = syntext.replace("Synset('",'')
# syntext = syntext.replace("')",'')
# syntext
# start_sn = wn.synset(syntext)
# start_sn

# %%
l
# Out:
# [['dog.n.01', 'dog.n.01'],
#  ['dog.n.01', 'basenji.n.01'],
#  ['dog.n.01', 'corgi.n.01'],
#  ['dog.n.01', 'cur.n.01'],
#  ['dog.n.01', 'dalmatian.n.02'],
#  ['dog.n.01', 'great_pyrenees.n.01'],
#  ['dog.n.01', 'griffon.n.02'],
#  ['dog.n.01', 'hunting_dog.n.01'],
#  ['dog.n.01', 'lapdog.n.01'],
#  ['dog.n.01', 'leonberg.n.01'],
#  ['dog.n.01', 'mexican_hairless.n.01'],
#  ['dog.n.01', 'newfoundland.n.01'],
#  ['dog.n.01', 'pooch.n.01'],
#  ['dog.n.01', 'poodle.n.01'],
#  ['dog.n.01', 'pug.n.01'],
#  ['dog.n.01', 'puppy.n.01'],
#  ['dog.n.01', 'spitz.n.01'],
#  ['dog.n.01', 'toy_dog.n.01'],
#  ['dog.n.01', 'working_dog.n.01'],
#  ['dog.n.01', 'frump.n.01'],
#  ['dog.n.01', 'dog.n.03'],
#  ['dog.n.01', 'cad.n.01'],
#  ['cad.n.01', 'perisher.n.01'],
#  ['dog.n.01', 'frank.n.02'],
#  ['frank.n.02', 'vienna_sausage.n.01'],
#  ['dog.n.01', 'pawl.n.01'],
#  ['dog.n.01', 'andiron.n.01'],
#  ['dog.n.01', 'chase.v.01'],
#  ['chase.v.01', 'hound.v.01'],
#  ['chase.v.01', 'quest.v.02'],
#  ['chase.v.01', 'run_down.v.07'],
#  ['chase.v.01', 'tree.v.03']]

# %%
getpc = get_parent_child('dog.n.01')
#data = [['dog1', 'dog'], ['dog2', 'basenji']]
start = wn.synset('dog.n.01').name()
finish = wn.synsets('gold')[0].name()
master_df = pd.DataFrame(data=getpc,columns=['parent','child'])
master_df['start'] = start
master_df['finish'] = finish
#master_df['start'] = master_df['start'].astype("string")
##crit = master_df['start']=='dog.n.01'
#f = master_df[master_df['start']=='dog.n.01']
#f
#crit = master_df['child']=='dog'
#f = master_df[crit]
#f

# %%
#master_df['path'] = master_df.apply(path_sim('child','finish'), axis=1)
##df['newcolumn'] = df.apply(lambda x: fxy(x['A'], x['B']), axis = 1)
master_df['path'] = master_df.apply(lambda x: path_sim1(x['child'], x['finish']), axis = 1)
#master_df.dtypes
#master_df
#master_df['path'] = pd.to_numeric(master_df['path'], errors='coerce')
#dog.lch_similarity(cat)

#dog.wup_similarity(cat)
master_df['dense_rank'] = master_df['path'].rank(method='dense',pct=True)
master_new = master_df.copy()
#master_new.head(10)
crit = master_new['dense_rank']>=0.5
#crit
tophalf = master_new[crit]

for index, row in tophalf.iterrows():
    #print(row['c1'], row['c2'])
    getpc = get_parent_child('dog.n.01')
    start = wn.synsets('dog')[0].name()
    finish = wn.synsets('gold')[0].name()
    master_df = pd.DataFrame(data=getpc,columns=['parent','child'])
    master_df['start'] = start
    master_df['finish'] = finish


#master_new.query('path>5')

#df[(df['Salary_in_1000']>=100)
#filtered_master = master_new[[crit]]
#gapminder_2002 = master_new[master_new['child']=='dog.n.01']
#gapminder_2002

#filtered_master = master_new[master_new['dense_rank'] == 2]
#master_new[crit]
#filtered_master

#master_new.filter(like='dog.n.01', axis=0)

# %%
filtered_master = master_new[master_new['dense_rank'] >= 0.5]
filtered_master
# Out:
#         parent          child     start     finish      path  dense_rank
# 19    dog.n.01     frump.n.01  dog.n.01  gold.n.01  0.055556    0.500000
# 20    dog.n.01       dog.n.03  dog.n.01  gold.n.01  0.058824    0.666667
# 21    dog.n.01       cad.n.01  dog.n.01  gold.n.01  0.058824    0.666667
# 22    cad.n.01  perisher.n.01  dog.n.01  gold.n.01  0.055556    0.500000
# 23    dog.n.01     frank.n.02  dog.n.01  gold.n.01  0.055556    0.500000
# 27    dog.n.01     chase.v.01  dog.n.01  gold.n.01  0.066667    1.000000
# 28  chase.v.01     hound.v.01  dog.n.01  gold.n.01  0.062500    0.833333
# 29  chase.v.01     quest.v.02  dog.n.01  gold.n.01  0.062500    0.833333
# 30  chase.v.01  run_down.v.07  dog.n.01  gold.n.01  0.062500    0.833333
# 31  chase.v.01      tree.v.03  dog.n.01  gold.n.01  0.062500    0.833333

# %%
def new_round(new_df_in,full_df_in):
    crit = new_df_in['dense_rank']>=0.5
    #crit
    tophalf = new_df_in[crit].copy()
    full_df = full_df_in.copy()
    start = wn.synsets('dog')[0].name()
    finish = wn.synsets('gold')[0].name()
    
    for index, row in tophalf.iterrows():
        #print(row['c1'], row['c2'])
        getpc = get_parent_child(row['child'])
        master_df = pd.DataFrame(data=getpc,columns=['parent','child'])
        master_df['start'] = start
        master_df['finish'] = finish
        master_df['path'] = master_df.apply(lambda x: path_sim1(x['child'], x['finish']), axis = 1)

    master_df['path'] = master_df.apply(lambda x: path_sim1(x['child'], x['finish']), axis = 1)
    master_df['dense_rank'] = master_df['path'].rank(method='dense',pct=True)
    full_df = full_df.append(master_df)
    max_path = full_df['path'].max()
    popular = full_df['child'][full_df['path']==max_path]
    print(popular, max_path)
    new_df = master_df.copy()
    if max_path == 1:
        return full_df
    else:
        new_round(new_df,full_df)

df = new_round(filtered_master,filtered_master)
# Out:
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 61, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 63, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 65, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 67, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 69, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 71, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 73, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 75, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 77, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 79, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 81, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 83, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 85, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 87, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 89, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 91, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 93, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 95, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 97, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 99, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 101, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 103, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 105, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 107, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 109, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 111, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 113, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 115, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 117, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 119, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 121, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 123, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 125, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 127, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 129, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 131, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 133, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 135, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 137, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 139, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 141, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 143, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 145, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 147, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 149, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 151, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 153, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 155, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 157, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 159, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 161, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 163, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 165, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 167, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 169, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 171, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 173, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 175, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 177, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 179, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 181, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 183, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 185, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 187, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 189, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 191, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 193, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 195, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 197, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 199, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 201, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 203, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 205, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 207, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 209, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 211, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 213, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 215, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 217, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 219, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 221, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 223, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 225, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 227, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 229, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 231, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 233, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 235, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 237, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 239, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 241, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 243, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 245, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 247, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 249, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 251, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 253, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 255, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 257, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 259, dtype: object 0.06666666666666667
# 27      chase.v.01
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
#           ...
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# 181      tree.n.02
# 185    corner.v.02
# Name: child, Length: 261, dtype: object 0.06666666666666667
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4553/186243944.py in <module>
#      27         new_round(new_df,full_df)
#      28
# ---> 29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# ...
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      25         return full_df
#      26     else:
# ---> 27         new_round(new_df,full_df)
#      28
#      29 df = new_round(filtered_master,filtered_master)
#
# /tmp/ipykernel_4553/186243944.py in new_round(new_df_in, full_df_in)
#      13         master_df['start'] = start
#      14         master_df['finish'] = finish
# ---> 15         master_df['path'] = master_df.apply(lambda x: path_sim1(x['child'], x['finish']), axis = 1)
#      16
#      17     master_df['path'] = master_df.apply(lambda x: path_sim1(x['child'], x['finish']), axis = 1)
#
# ~/.local/share/virtualenvs/JokeIdeaGenerator-fEmoDMJg/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~/.local/share/virtualenvs/JokeIdeaGenerator-fEmoDMJg/lib/python3.8/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~/.local/share/virtualenvs/JokeIdeaGenerator-fEmoDMJg/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ~/.local/share/virtualenvs/JokeIdeaGenerator-fEmoDMJg/lib/python3.8/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# /tmp/ipykernel_4553/186243944.py in <lambda>(x)
#      13         master_df['start'] = start
#      14         master_df['finish'] = finish
# ---> 15         master_df['path'] = master_df.apply(lambda x: path_sim1(x['child'], x['finish']), axis = 1)
#      16
#      17     master_df['path'] = master_df.apply(lambda x: path_sim1(x['child'], x['finish']), axis = 1)
#
# /tmp/ipykernel_4553/522455563.py in path_sim1(child, finish)
#       2     child_sn = wn.synset(child)
#       3     finish_sn = wn.synset(finish)
# ----> 4     ps = child_sn.path_similarity(finish_sn)
#       5     return ps
#
# ~/.local/share/virtualenvs/JokeIdeaGenerator-fEmoDMJg/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py in path_similarity(self, other, verbose, simulate_root)
#     842         """
#     843
# --> 844         distance = self.shortest_path_distance(
#     845             other,
#     846             simulate_root=simulate_root and (self._needs_root() or other._needs_root()),
#
# ~/.local/share/virtualenvs/JokeIdeaGenerator-fEmoDMJg/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py in shortest_path_distance(self, other, simulate_root)
#     800             return 0
#     801
# --> 802         dist_dict1 = self._shortest_hypernym_paths(simulate_root)
#     803         dist_dict2 = other._shortest_hypernym_paths(simulate_root)
#     804
#
# ~/.local/share/virtualenvs/JokeIdeaGenerator-fEmoDMJg/lib/python3.8/site-packages/nltk/corpus/reader/wordnet.py in _shortest_hypernym_paths(self, simulate_root)
#     772
#     773             depth += 1
# --> 774             queue.extend((hyp, depth) for hyp in s._hypernyms())
#     775             queue.extend((hyp, depth) for hyp in s._instance_hypernyms())
#     776
#
# KeyboardInterrupt:

# %%
start = wn.synsets('dog')[0]
finish = wn.synsets('gold')[0]
gold
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4553/1232907626.py in <module>
#       1 start = wn.synsets('dog')[0]
#       2 finish = wn.synsets('gold')[0]
# ----> 3 gold
#
# NameError: name 'gold' is not defined

# %%
print('hypernyms' ,dog.hypernyms())

# %%
##[Synset('canine.n.02'), Synset('domestic_animal.n.01')]
dog.hyponyms()
##[Synset('basenji.n.01'), Synset('corgi.n.01'), Synset('cur.n.01'), Synset('dalmatian.n.02'), ...]
dog.member_holonyms()
##[Synset('canis.n.01'), Synset('pack.n.06')]
dog.root_hypernyms()
##[Synset('entity.n.01')]
wn.synset('dog.n.01').lowest_common_hypernyms(wn.synset('cat.n.01'))
##[Synset('carnivore.n.01')]

# %%
##dog.lowest_common_hypernyms(cat)

# %%
#Each synset contains one or more lemmas, which represent a specific sense of a specific word.

#Note that some relations are defined by WordNet only over Lemmas:

good = wn.synset('good.a.01')
#good.antonyms()
#Traceback (most recent call last):
#  File "<stdin>", line 1, in <module>
#AttributeError: 'Synset' object has no attribute 'antonyms'
good.lemmas()[0].antonyms()
#[Lemma('bad.a.01.bad')]

#The relations that are currently defined in this way are antonyms, derivationally_related_forms and pertainyms.

#If you know the byte offset used to identify a synset in the original Princeton WordNet data file, you can use that to instantiate the synset in NLTK:

#>>> wn.synset_from_pos_and_offset('n', 4543158)
#Synset('wagon.n.01')

# %%
#Lemmas

eat = wn.lemma('eat.v.03.eat')
eat
#Lemma('feed.v.06.eat')
print(eat.key())
#eat%2:34:02::
eat.count()
#4
wn.lemma_from_key(eat.key())
#Lemma('feed.v.06.eat')
wn.lemma_from_key(eat.key()).synset()
#Synset('feed.v.06')
wn.lemma_from_key('feebleminded%5:00:00:retarded:00')
#Lemma('backward.s.03.feebleminded')
for lemma in wn.synset('eat.v.03').lemmas():
    print(lemma, lemma.count())
#...
#Lemma('feed.v.06.feed') 3
#Lemma('feed.v.06.eat') 4
for lemma in wn.lemmas('eat', 'v'):
    print(lemma, lemma.count())

#Lemma('eat.v.01.eat') 61
#Lemma('eat.v.02.eat') 13
#Lemma('feed.v.06.eat') 4
#Lemma('eat.v.04.eat') 0
#Lemma('consume.v.05.eat') 0
#Lemma('corrode.v.01.eat') 0
wn.lemma('jump.v.11.jump')
#Lemma('jump.v.11.jump')

# %%
#Lemmas can also have relations between them:

vocal = wn.lemma('vocal.a.01.vocal')
vocal.derivationally_related_forms()
#[Lemma('vocalize.v.02.vocalize')]
vocal.pertainyms()
#[Lemma('voice.n.02.voice')]
vocal.antonyms()
#[Lemma('instrumental.a.01.instrumental')]

#The three relations above exist only on lemmas, not on synsets.

# %%
#Similarity

dog = wn.synset('dog.n.01')
cat = wn.synset('cat.n.01')

hit = wn.synset('hit.v.01')
slap = wn.synset('slap.v.01')

#synset1.path_similarity(synset2):
#Return a score denoting how similar two word senses are, based on the shortest path
##that connects the senses in the is-a (hypernym/hypnoym) taxonomy.
##The score is in the range 0 to 1. By default, there is now a fake root node added to verbs
##so for cases where previously a path could not be found—and None
##was returned—it should return a value. The old behavior can be achieved by
##setting simulate_root to be False. A score of 1 represents identity i.e. comparing a sense
##with itself will return 1.

dog.path_similarity(cat)
#0.2...

hit.path_similarity(slap)
#0.142...

wn.path_similarity(hit, slap)
#0.142...

print(hit.path_similarity(slap, simulate_root=False))
#None

print(wn.path_similarity(hit, slap, simulate_root=False))
#None

##synset1.lch_similarity(synset2):
##Leacock-Chodorow Similarity: Return a score denoting how similar two word senses are,
##based on the shortest path that connects the senses (as above) and the maximum depth
##of the taxonomy in which the senses occur. The relationship is given as -log(p/2d)
##where p is the shortest path length and d the taxonomy depth.

dog.lch_similarity(cat)
##2.028...

hit.lch_similarity(slap)
##1.312...

wn.lch_similarity(hit, slap)
#1.312...

print(hit.lch_similarity(slap, simulate_root=False))
##None

print(wn.lch_similarity(hit, slap, simulate_root=False))
#None

# %%
'''synset1.wup_similarity(synset2):
Wu-Palmer Similarity: Return a score denoting how similar two word senses are,
    based on the depth of the two senses in the taxonomy and that of their
    Least Common Subsumer (most specific ancestor node). Note that at this
    time the scores given do _not_ always agree with those given by
    Pedersen’s Perl implementation of Wordnet Similarity.
'''

'''
The LCS does not necessarily feature in the shortest path connecting the two senses,
as it is by definition the common ancestor deepest in the taxonomy,
not closest to the two senses. Typically, however, it will so feature.
Where multiple candidates for the LCS exist, that whose shortest path to
the root node is the longest will be selected.
Where the LCS has multiple paths to the root, the longer path is used
for the purposes of the calculation.
'''

dog.wup_similarity(cat,verbose=True)
##0.857...

# %%
hit.wup_similarity(slap)
##0.25

wn.wup_similarity(hit, slap)
##0.25

print(hit.wup_similarity(slap, simulate_root=False))
##None

print(wn.wup_similarity(hit, slap, simulate_root=False))
##None

# %%
#Access to all Synsets

#Iterate over all the noun synsets:

for synset in list(wn.all_synsets('n'))[:10]:
    print(synset)

#Synset('entity.n.01')
#Synset('physical_entity.n.01')
#Synset('abstraction.n.06')
#Synset('thing.n.12')
#Synset('object.n.01')
#Synset('whole.n.02')
#Synset('congener.n.03')
#Synset('living_thing.n.01')
#Synset('organism.n.01')
#Synset('benthos.n.02')

#Get all synsets for this word, possibly restricted by POS:

wn.synsets('dog')
#[Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), ...]
wn.synsets('dog', pos='v')
#[Synset('chase.v.01')]

#Walk through the noun synsets looking at their hypernyms:

from itertools import islice
for synset in islice(wn.all_synsets('n'), 5):
    print(synset, synset.hypernyms())

#Synset('entity.n.01') []
#Synset('physical_entity.n.01') [Synset('entity.n.01')]
#Synset('abstraction.n.06') [Synset('entity.n.01')]
#Synset('thing.n.12') [Synset('physical_entity.n.01')]
#Synset('object.n.01') [Synset('physical_entity.n.01')]

# %%
wn.synset('code.n.03').topic_domains()
#[Synset('computer_science.n.01')]
wn.synset('pukka.a.01').region_domains()
##[Synset('india.n.01')]
wn.synset('freaky.a.01').usage_domains()

# %%
#Endlessness vs. intractability in relation trees
##1. Endlessness

'''Until NLTK v. 3.5, the tree() function looped forever on symmetric relations 
(verb_groups, attributes, and most also_sees). But in the current version, tree()
now detects and discards these cycles:
'''

from pprint import pprint
pprint(wn.synset('bound.a.01').tree(lambda s:s.also_sees()))
#[Synset('bound.a.01'),
# [Synset('unfree.a.02'),
#  [Synset('confined.a.02'),
#   [Synset('restricted.a.01'), [Synset('classified.a.02')]]],
#  [Synset('dependent.a.01')],
#  [Synset('restricted.a.01'),
#   [Synset('classified.a.02')],
#   [Synset('confined.a.02')]]]]

#Specifying the “cut_mark” parameter increases verbosity,
#so that the cycles are mentioned in the output,
#together with the level where they occur:

pprint(wn.synset('bound.a.01').tree(lambda s:s.also_sees(),cut_mark='...'))
#[Synset('bound.a.01'),
# [Synset('unfree.a.02'),
#  "Cycle(Synset('bound.a.01'),-3,...)",
#  [Synset('confined.a.02'),
#   [Synset('restricted.a.01'),
#    [Synset('classified.a.02')],
#    "Cycle(Synset('confined.a.02'),-5,...)",
#    "Cycle(Synset('unfree.a.02'),-5,...)"],
#   "Cycle(Synset('unfree.a.02'),-4,...)"],
#  [Synset('dependent.a.01'), "Cycle(Synset('unfree.a.02'),-4,...)"],
#  [Synset('restricted.a.01'),
#   [Synset('classified.a.02')],
#   [Synset('confined.a.02'),
#    "Cycle(Synset('restricted.a.01'),-5,...)",
#    "Cycle(Synset('unfree.a.02'),-5,...)"],
#   "Cycle(Synset('unfree.a.02'),-4,...)"]]]

# %%
#2. Intractability

#However, even after discarding the infinite cycles, some trees can remain intractable,
#due to combinatorial explosion in a relation. This happens in WordNet, because the also.sees()
##relation has a big Strongly Connected Component (_SCC_) consisting in 758 synsets,
#where any member node is transitively connected by the same relation,
#to all other members of the same SCC. This produces intractable relation trees for each
#of these 758 synsets, i. e. trees that are too big to compute or display on any computer.

#For example, the synset ‘concrete.a.01’ is a member of the largest SCC,
##so its also_sees() tree is intractable, and can normally only be handled by
#limiting the “depth” parameter to display a small number of levels:

from pprint import pprint
pprint(wn.synset('concrete.a.01').tree(lambda s:s.also_sees(),cut_mark='...',depth=2))

# %%
##2.1 First solution: acyclic_tree()

##On the other hand, the new acyclic_tree() function is able to also handle the intractable cases.
##The also_sees() acyclic tree of ‘concrete.a.01’ is several hundred lines long,
##so here is a simpler example, concerning a much smaller SCC: counting only five members,
##the SCC that includes ‘bound.a.01’ is tractable with the normal tree() function, as seen above.

#But while tree() only prunes redundancy within local branches,
##acyclic_tree prunes the tree globally, thus discarding any additional redundancy,
##and produces a tree that includes all reachable nodes (i. e. a _spanning tree_).
##This tree is _minimal_ because it includes the reachable nodes only once,
##but it is not necessarily a _Minimum Spanning Tree_ (MST), because the Depth-first search
##strategy does not guarantee that nodes are reached through the lowest number of links
##(as Breadth-first search would).

pprint(wn.synset('bound.a.01').acyclic_tree(lambda s:s.also_sees()))

#Again, specifying the “cut_mark” parameter increases verbosity,
#so that the cycles are mentioned in the output, together with the level where they occur:

pprint(wn.synset('bound.a.01').acyclic_tree(lambda s:s.also_sees(),cut_mark='...'))

# %%
#2.2 Better solution: mst()

'''A Minimum Spanning Tree (MST) spans all the nodes of a relation subgraph once,
while guaranteeing that each node is reached through the shortest path possible.
In unweighted relation graphs like WordNet, a MST can be computed very efficiently
in linear time, using Breadth-First Search (BFS). Like acyclic_tree(),
the new “unweighted_minimum_spanning_tree()” function (imported in the Wordnet module as “mst”)
handles intractable trees, such as the example discussed above:
    “wn.synset(‘concrete.a.01’).mst(lambda s:s.also_sees())”.

But, while the also_sees() acyclic_tree of ‘bound.a.01’ reaches ‘classified.a.02’ through four links, using depth-first search as seen above (bound.a.01 > unfree.a.02 > confined.a.02 > restricted.a.01 > classified.a.02), in the following MST, the path to ‘classified.a.02’ is the shortest possible, consisting only in three links (bound.a.01 > unfree.a.02 > restricted.a.01 > classified.a.02):
'''

pprint(wn.synset('bound.a.01').mst(lambda s:s.also_sees()))

# %%
pprint(wn.synset('dog.n.01').mst(lambda s:s.also_sees()))

# %%
def getwordnetwork(word_in):
    #word = Word("dog")
    synonyms = []
    master = word_in.synsets[0]
    for syn in word_in.synsets:
        print(syn)
        append_this = [master,syn]
        synonyms.append(append_this)
    
    #print(synonyms)
    ##k = [[1, 2], [4], [5, 6, 2], [1, 2], [3], [4]]
    new_synonyms = []
    for elem in synonyms:
        #print(elem)
        if elem[0] != elem[1] and elem not in new_synonyms:
            new_synonyms.append(elem)
    return new_synonyms

# %%
word = Word("dog")
word.synsets
word_df = getwordnetwork(word)

# %%
df = pd.DataFrame(data=word_df,columns=[['parent','child']])

# %%
df
